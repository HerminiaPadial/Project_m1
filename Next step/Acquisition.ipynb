# %% [markdown]
# # Acquisition methods

# %%
# Import pandas 
import pandas as pd

#Import duckdb databases system
import duckdb

# Import libraries to create environment variables
import requests

# %%
bm_path= './Data/bicimad1.db'

# %%
center= 'https://datos.madrid.es/egob/catalogo/200304-0-centros-culturales.json'

# %%
def acquisition(file_path1, table_name, file_path2):
    con = duckdb.connect(file_path1)
    df_acquisition1 = con.sql((f"SELECT * FROM {table_name}")).df()  #FOR BICIMAD
    
    c_cult_json_data = requests.get(file_path2).json()
    df_acquisition2 = pd.json_normalize(c_cult_json_data['@graph'])         #FOR CENTERS
    
    df_resultado = pd.concat([df_acquisition1, df_acquisition2], axis=1)
    return df_resultado

# %%
df_acquisition = acquisition('./Data/bicimad1.db', 'bicimad_stations', 'https://datos.madrid.es/egob/catalogo/200304-0-centros-culturales.json')
# Out:
#       id                          name  light number
# 0      1         1a - Puerta del Sol A      3     1a  \
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate
# 0                                  Puerta del Sol nº 1         1  \
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ..                                                 ...       ...
# 259  Avenida Juan de Herrera frente a la calle Paul...         1
# 260  Avenida de la Complutense (Metro Ciudad Univer...         1
# 261  Avenida de la Complutense (Metro Ciudad Univer...         1
# 262          Calle José Antonio Novais frente al nº 12         1
# 263                          Avenida Complutense nº 23         1
#
#      no_available  total_bases  dock_bikes  free_bases  ...  address.locality
# 0               1           30           0           0  ...            MADRID  \
# 1               1           30           0           0  ...            MADRID
# 2               1           24           0           0  ...            MADRID
# 3               0           18           9           9  ...            MADRID
# 4               0           24          23           1  ...            MADRID
# ..            ...          ...         ...         ...  ...               ...
# 259             0           24           3          19  ...               NaN
# 260             0           24           9          14  ...               NaN
# 261             0           24          12          10  ...               NaN
# 262             0           24          12          10  ...               NaN
# 263             0           24           8          16  ...               NaN
#
#     address.postal-code   address.street-address location.latitude
# 0                 28033          CALLE JAZMIN 46         40.479608  \
# 1                 28027  CALLE JOSE DEL HIERRO 3         40.436300
# 2                 28044    AVENIDA LAS AGUILAS 2         40.384939
# 3                 28005           CALLE CASINO 3         40.406818
# 4                 28042      CALLE BOTICA 7 y 10         40.473402
# ..                  ...                      ...               ...
# 259                 NaN                      NaN               NaN
# 260                 NaN                      NaN               NaN
# 261                 NaN                      NaN               NaN
# 262                 NaN                      NaN               NaN
# 263                 NaN                      NaN               NaN
#
#     location.longitude                     organization.organization-desc
# 0            -3.665799  Ubicado en el Centro de Mayores Carmen Laforet...  \
# 1            -3.650410   Mantenimiento: Dependiente de la Junta Munici...
# 2            -3.764196    Metro de Madrid. Línea 5. Estación: Aluche. ...
# 3            -3.704690    Metro: Embajadores (líneas 3 y 5)  Bus: M1, ...
# 4            -3.578523       Metro: Barajas (línea 8)  Bus: 101, 105, 115
# ..                 ...                                                ...
# 259                NaN                                                NaN
# 260                NaN                                                NaN
# 261                NaN                                                NaN
# 262                NaN                                                NaN
# 263                NaN                                                NaN
#
#     organization.accesibility
# 0                           1  \
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ..                        ...
# 259                       NaN
# 260                       NaN
# 261                       NaN
# 262                       NaN
# 263                       NaN
#
#                                  organization.schedule
# 0                                     De 9 a 21 horas.  \
# 1
# 2
# 3    De apertura   De lunes a viernes, de 8:30 a 21...
# 4    De lunes a viernes, de 9 a 14 y de 15 a 17 hor...
# ..                                                 ...
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
#
#                                  organization.services
# 0              Aforo: 190 personas Zona wifi Cafetería  \
# 1
# 2    Sala de exposiciones. Salón de actos y auditor...
# 3    Orientación sobre recursos sociales a vecinos....
# 4    3 salas de exposiciones Salón de actos / audit...
# ..                                                 ...
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
#
#                         organization.organization-name
# 0             Auditorio Carmen Laforet (Ciudad Lineal)
# 1           Auditorio al aire libre. Parque del Calero
# 2    Auditorio y sala de exposiciones Paco de Lucía...
# 3                Centro Comunitario Casino de la Reina
# 4    Centro Cultural - Centro Socio Cultural Villa ...
# ..                                                 ...
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
#
# [264 rows x 30 columns]

# %% [markdown]
# # Wrangling

# %%
bicimad_df_filter= bicimad_df[['name', 'address', 'geometry.coordinates']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 bicimad_df_filter= bicimad_df[['name', 'address', 'geometry.coordinates']]
#
# NameError: name 'bicimad_df' is not defined
